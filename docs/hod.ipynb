# %% [markdown]
# the hods are kind of ugh
#
# # hod
#
# to test out a custom hod with arbitrary parameters (ie you only want to change certain parameters you care about)--the rest will
#
# TODO: check how much you need to specify bc abacus also deals w the defaults no? so maybe this doesnt matter?
#
#
#
# - `data/lrg_params.csv` fiducial HOD parameters come from DESI DR2 AbacusHF-v2 mock production documentation (CrossAnalysisInfrastructureWG/LSSMocks/DR2HFAbacusMocks).

# %% [markdown]
# ## dependencies
#
# what are the dependencies of hod params on rsd signals?
